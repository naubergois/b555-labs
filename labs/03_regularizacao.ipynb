# %% [markdown]
# # Aula 03 — Capacidade e regularização (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Breast Cancer + moons**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-028** … **EX-040** (13 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-028** — A/B Breast Cancer → `labs/exercicios/ex_028.py`
# - **EX-029** — L2 como freio → `labs/exercicios/ex_029.py`
# - **EX-030** — Early na profunda → `labs/exercicios/ex_030.py`
# - **EX-031** — Capacidade → `labs/exercicios/ex_031.py`
# - **EX-032** — Dropout (conceito) → `labs/exercicios/ex_032.py`
# - **EX-033** — Escolha pela validação → `labs/exercicios/ex_033.py`
# - **EX-034** — Moons ruidoso → `labs/exercicios/ex_034.py`
# - **EX-035** — Noise 0,5 → `labs/exercicios/ex_035.py`
# - **EX-036** — Gap treino−teste → `labs/exercicios/ex_036.py`
# - **EX-037** — Prova decorada → `labs/exercicios/ex_037.py`
# - **EX-038** — Parâmetros vs dados → `labs/exercicios/ex_038.py`
# - **EX-039** — Freios úteis → `labs/exercicios/ex_039.py`
# - **EX-040** — Uma frase → `labs/exercicios/ex_040.py`

# %% [markdown]
# ## EX-028 — A/B Breast Cancer
#
# Compare rasa vs profunda no mesmo split. Quem generaliza melhor?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_028.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_028.py
# %run -i labs/exercicios/ex_028.py

# %% [markdown]
# ## EX-029 — L2 como freio
#
# Com alpha=0,05 na profunda, o gap muda?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_029.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_029.py
# %run -i labs/exercicios/ex_029.py

# %% [markdown]
# ## EX-030 — Early na profunda
#
# Early stopping reduz epochs? Quanto?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_030.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_030.py
# %run -i labs/exercicios/ex_030.py

# %% [markdown]
# ## EX-031 — Capacidade
#
# Rede maior sempre é melhor? Sim/Não + por quê.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_031.py`
#
# <details><summary>Gabarito curto</summary>
#
# não
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_031.py
# %run -i labs/exercicios/ex_031.py

# %% [markdown]
# ## EX-032 — Dropout (conceito)
#
# Dropout desliga unidades no treino. No teste, o que muda?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_032.py`
#
# <details><summary>Gabarito curto</summary>
#
# usa rede 'média' / sem desligar
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_032.py
# %run -i labs/exercicios/ex_032.py

# %% [markdown]
# ## EX-033 — Escolha pela validação
#
# Complete: escolho pela _____; guardo o _____ para o fim.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_033.py`
#
# <details><summary>Gabarito curto</summary>
#
# validação; teste
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_033.py
# %run -i labs/exercicios/ex_033.py

# %% [markdown]
# ## EX-034 — Moons ruidoso
#
# make_moons noise=0,35: quem sofre mais sem regularização?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_034.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_034.py
# %run -i labs/exercicios/ex_034.py

# %% [markdown]
# ## EX-035 — Noise 0,5
#
# Suba noise para 0,5 e repita o A/B (2 configs).
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_035.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_035.py
# %run -i labs/exercicios/ex_035.py

# %% [markdown]
# ## EX-036 — Gap treino−teste
#
# Plote barras do gap das 4 configs no Cancer.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_036.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_036.py
# %run -i labs/exercicios/ex_036.py

# %% [markdown]
# ## EX-037 — Prova decorada
#
# Overfitting é analogia de quê nesta trilha?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_037.py`
#
# <details><summary>Gabarito curto</summary>
#
# decorar a prova
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_037.py
# %run -i labs/exercicios/ex_037.py

# %% [markdown]
# ## EX-038 — Parâmetros vs dados
#
# Se #params ≫ #exemplos, o risco principal é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_038.py`
#
# <details><summary>Gabarito curto</summary>
#
# overfit
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_038.py
# %run -i labs/exercicios/ex_038.py

# %% [markdown]
# ## EX-039 — Freios úteis
#
# Liste 3 freios vistos na aula.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_039.py`
#
# <details><summary>Gabarito curto</summary>
#
# L2, early stopping, dropout
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_039.py
# %run -i labs/exercicios/ex_039.py

# %% [markdown]
# ## EX-040 — Uma frase
#
# Capacidade propõe; dados e freios ______.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_040.py`
#
# <details><summary>Gabarito curto</summary>
#
# condicionam
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_040.py
# %run -i labs/exercicios/ex_040.py

# %% [markdown]
# ## Fecho da aula 03
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
