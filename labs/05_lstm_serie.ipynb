# %% [markdown]
# # Aula 05 — Sequências / LSTM (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Airline Passengers**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-055** … **EX-067** (13 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-055** — Série Airline → `labs/exercicios/ex_055.py`
# - **EX-056** — Janela 12 → `labs/exercicios/ex_056.py`
# - **EX-057** — Baseline persistência → `labs/exercicios/ex_057.py`
# - **EX-058** — MLP na janela → `labs/exercicios/ex_058.py`
# - **EX-059** — LSTM → `labs/exercicios/ex_059.py`
# - **EX-060** — Split cronológico → `labs/exercicios/ex_060.py`
# - **EX-061** — Vazamento temporal → `labs/exercicios/ex_061.py`
# - **EX-062** — Quando LSTM perde → `labs/exercicios/ex_062.py`
# - **EX-063** — Estado oculto → `labs/exercicios/ex_063.py`
# - **EX-064** — Vanishing gradient → `labs/exercicios/ex_064.py`
# - **EX-065** — WhatsApp em ordem → `labs/exercicios/ex_065.py`
# - **EX-066** — Métrica de série → `labs/exercicios/ex_066.py`
# - **EX-067** — Sem espiar o futuro → `labs/exercicios/ex_067.py`

# %% [markdown]
# ## EX-055 — Série Airline
#
# Plote a série Airline Passengers.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_055.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_055.py
# %run -i labs/exercicios/ex_055.py

# %% [markdown]
# ## EX-056 — Janela 12
#
# Com janela=12, quantos pares (X,y) restam?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_056.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_056.py
# %run -i labs/exercicios/ex_056.py

# %% [markdown]
# ## EX-057 — Baseline persistência
#
# Calcule MAE/RMSE da persistência no teste.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_057.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_057.py
# %run -i labs/exercicios/ex_057.py

# %% [markdown]
# ## EX-058 — MLP na janela
#
# Treine MLP e compare MAE com a baseline.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_058.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_058.py
# %run -i labs/exercicios/ex_058.py

# %% [markdown]
# ## EX-059 — LSTM
#
# Treine LSTM e plote real vs pred vs persistência.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_059.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_059.py
# %run -i labs/exercicios/ex_059.py

# %% [markdown]
# ## EX-060 — Split cronológico
#
# Por que não embaralhar a série?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_060.py`
#
# <details><summary>Gabarito curto</summary>
#
# vazar futuro
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_060.py
# %run -i labs/exercicios/ex_060.py

# %% [markdown]
# ## EX-061 — Vazamento temporal
#
# Usar y[t+1] como feature de x[t] é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_061.py`
#
# <details><summary>Gabarito curto</summary>
#
# vazamento / trapaça
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_061.py
# %run -i labs/exercicios/ex_061.py

# %% [markdown]
# ## EX-062 — Quando LSTM perde
#
# Aumente ruído sintético: LSTM ainda ganha?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_062.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_062.py
# %run -i labs/exercicios/ex_062.py

# %% [markdown]
# ## EX-063 — Estado oculto
#
# RNN/LSTM carregam o quê entre passos?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_063.py`
#
# <details><summary>Gabarito curto</summary>
#
# estado / memória
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_063.py
# %run -i labs/exercicios/ex_063.py

# %% [markdown]
# ## EX-064 — Vanishing gradient
#
# Sequências longas sofrem com…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_064.py`
#
# <details><summary>Gabarito curto</summary>
#
# gradiente sumindo
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_064.py
# %run -i labs/exercicios/ex_064.py

# %% [markdown]
# ## EX-065 — WhatsApp em ordem
#
# A analogia de sequência desta trilha é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_065.py`
#
# <details><summary>Gabarito curto</summary>
#
# WhatsApp em ordem
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_065.py
# %run -i labs/exercicios/ex_065.py

# %% [markdown]
# ## EX-066 — Métrica de série
#
# MAE vs RMSE: qual pune mais outliers?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_066.py`
#
# <details><summary>Gabarito curto</summary>
#
# RMSE
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_066.py
# %run -i labs/exercicios/ex_066.py

# %% [markdown]
# ## EX-067 — Sem espiar o futuro
#
# Escreva a frase-guia da aula de sequências.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_067.py`
#
# <details><summary>Gabarito curto</summary>
#
# sem espiar o futuro
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_067.py
# %run -i labs/exercicios/ex_067.py

# %% [markdown]
# ## Fecho da aula 05
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
