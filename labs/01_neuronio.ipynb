# %% [markdown]
# # Aula 01 — Neurônio artificial (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Iris (sklearn/UCI)**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-001** … **EX-014** (14 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-001** — Pesos manuais na Iris → `labs/exercicios/ex_001.py`
# - **EX-002** — Treino do neurônio → `labs/exercicios/ex_002.py`
# - **EX-003** — Curva sigmoid → `labs/exercicios/ex_003.py`
# - **EX-004** — Efeito do bias → `labs/exercicios/ex_004.py`
# - **EX-005** — Degrau vs sigmoid → `labs/exercicios/ex_005.py`
# - **EX-006** — Geometria da fronteira → `labs/exercicios/ex_006.py`
# - **EX-007** — Nuvens próximas → `labs/exercicios/ex_007.py`
# - **EX-008** — Derivada do peso → `labs/exercicios/ex_008.py`
# - **EX-009** — Regressão logística → `labs/exercicios/ex_009.py`
# - **EX-010** — Limiar 0,5 → `labs/exercicios/ex_010.py`
# - **EX-011** — Escala das features → `labs/exercicios/ex_011.py`
# - **EX-012** — O que o neurônio NÃO faz → `labs/exercicios/ex_012.py`
# - **EX-013** — Montar diagrama → `labs/exercicios/ex_013.py`
# - **EX-014** — Frase-guia → `labs/exercicios/ex_014.py`

# %% [markdown]
# ## EX-001 — Pesos manuais na Iris
#
# Com Iris binária (pétala), teste w=[0.2,-1] e w=[1,1]. Qual acurácia de cada um?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_001.py`
#
# <details><summary>Gabarito curto</summary>
#
# ruim ~baixa; ok ~alta
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_001.py
# %run -i labs/exercicios/ex_001.py

# %% [markdown]
# ## EX-002 — Treino do neurônio
#
# Treine 80 epochs e plote a loss. A loss final ficou abaixo de 0,05?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_002.py`
#
# <details><summary>Gabarito curto</summary>
#
# sim, tipicamente
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_002.py
# %run -i labs/exercicios/ex_002.py

# %% [markdown]
# ## EX-003 — Curva sigmoid
#
# Plote σ(z) de −6 a 6. Em z=0, qual o valor?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_003.py`
#
# <details><summary>Gabarito curto</summary>
#
# 0,5
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_003.py
# %run -i labs/exercicios/ex_003.py

# %% [markdown]
# ## EX-004 — Efeito do bias
#
# Fixe w=[1,1] e compare b=−0,5 vs b=−1,5 num ponto x=[2,1]. A classe muda?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_004.py`
#
# <details><summary>Gabarito curto</summary>
#
# sim
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_004.py
# %run -i labs/exercicios/ex_004.py

# %% [markdown]
# ## EX-005 — Degrau vs sigmoid
#
# Troque a ativação por degrau. A fronteira fica suave ou abrupta?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_005.py`
#
# <details><summary>Gabarito curto</summary>
#
# abrupta
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_005.py
# %run -i labs/exercicios/ex_005.py

# %% [markdown]
# ## EX-006 — Geometria da fronteira
#
# Com 2D, a equação w·x+b=0 é uma reta. O bias move o quê?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_006.py`
#
# <details><summary>Gabarito curto</summary>
#
# o intercepto / desloca a reta
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_006.py
# %run -i labs/exercicios/ex_006.py

# %% [markdown]
# ## EX-007 — Nuvens próximas
#
# Aproxime as médias das blobs até a acurácia cair abaixo de 70%. Qual distância?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_007.py`
#
# <details><summary>Gabarito curto</summary>
#
# ~0,4–0,8
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_007.py
# %run -i labs/exercicios/ex_007.py

# %% [markdown]
# ## EX-008 — Derivada do peso
#
# ∂z/∂xⱼ = wⱼ. Se w₁>0 e x₁ sobe, z sobe ou desce?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_008.py`
#
# <details><summary>Gabarito curto</summary>
#
# sobe
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_008.py
# %run -i labs/exercicios/ex_008.py

# %% [markdown]
# ## EX-009 — Regressão logística
#
# Um neurônio com sigmoid tem a mesma forma de qual baseline clássico?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_009.py`
#
# <details><summary>Gabarito curto</summary>
#
# regressão logística
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_009.py
# %run -i labs/exercicios/ex_009.py

# %% [markdown]
# ## EX-010 — Limiar 0,5
#
# Com p=0,49 e p=0,51, quais classes no limiar 0,5?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_010.py`
#
# <details><summary>Gabarito curto</summary>
#
# 0 e 1
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_010.py
# %run -i labs/exercicios/ex_010.py

# %% [markdown]
# ## EX-011 — Escala das features
#
# Por que StandardScaler ajuda antes do neurônio na Iris?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_011.py`
#
# <details><summary>Gabarito curto</summary>
#
# pesos comparáveis / convergência
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_011.py
# %run -i labs/exercicios/ex_011.py

# %% [markdown]
# ## EX-012 — O que o neurônio NÃO faz
#
# O neurônio 'entende' o significado de pétala? Sim ou não?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_012.py`
#
# <details><summary>Gabarito curto</summary>
#
# não
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_012.py
# %run -i labs/exercicios/ex_012.py

# %% [markdown]
# ## EX-013 — Montar diagrama
#
# Desenhe (matplotlib) entrada→Σ→φ→saída com 2 entradas.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_013.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_013.py
# %run -i labs/exercicios/ex_013.py

# %% [markdown]
# ## EX-014 — Frase-guia
#
# Complete: a rede ______; nós ______.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_014.py`
#
# <details><summary>Gabarito curto</summary>
#
# calcula; decidimos
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_014.py
# %run -i labs/exercicios/ex_014.py

# %% [markdown]
# ## Fecho da aula 01
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
