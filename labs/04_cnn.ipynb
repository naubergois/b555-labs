# %% [markdown]
# # Aula 04 — CNN / Visão (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Fashion-MNIST / Digits**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-041** … **EX-054** (14 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-041** — Amostra Fashion-MNIST → `labs/exercicios/ex_041.py`
# - **EX-042** — CNN pequena → `labs/exercicios/ex_042.py`
# - **EX-043** — Curvas CNN → `labs/exercicios/ex_043.py`
# - **EX-044** — Erros no teste → `labs/exercicios/ex_044.py`
# - **EX-045** — Filtro compartilhado → `labs/exercicios/ex_045.py`
# - **EX-046** — Convolução 3×3 → `labs/exercicios/ex_046.py`
# - **EX-047** — Pooling → `labs/exercicios/ex_047.py`
# - **EX-048** — Sem Conv2D → `labs/exercicios/ex_048.py`
# - **EX-049** — Transfer learning (conceito) → `labs/exercicios/ex_049.py`
# - **EX-050** — Domínio diferente → `labs/exercicios/ex_050.py`
# - **EX-051** — Canais → `labs/exercicios/ex_051.py`
# - **EX-052** — Normalização /255 → `labs/exercicios/ex_052.py`
# - **EX-053** — Lanterna no mural → `labs/exercicios/ex_053.py`
# - **EX-054** — Inspecionar erros → `labs/exercicios/ex_054.py`

# %% [markdown]
# ## EX-041 — Amostra Fashion-MNIST
#
# Mostre um grid 2×5 de imagens do treino com rótulos.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_041.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_041.py
# %run -i labs/exercicios/ex_041.py

# %% [markdown]
# ## EX-042 — CNN pequena
#
# Treine 5 epochs a CNN didática. Qual val_acc final?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_042.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_042.py
# %run -i labs/exercicios/ex_042.py

# %% [markdown]
# ## EX-043 — Curvas CNN
#
# Plote accuracy e loss de treino/val.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_043.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_043.py
# %run -i labs/exercicios/ex_043.py

# %% [markdown]
# ## EX-044 — Erros no teste
#
# Mostre 8 erros com y vs ŷ. Qual par mais comum?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_044.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_044.py
# %run -i labs/exercicios/ex_044.py

# %% [markdown]
# ## EX-045 — Filtro compartilhado
#
# Por que um kernel compartilhado economiza parâmetros?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_045.py`
#
# <details><summary>Gabarito curto</summary>
#
# mesmo padrão em qualquer canto
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_045.py
# %run -i labs/exercicios/ex_045.py

# %% [markdown]
# ## EX-046 — Convolução 3×3
#
# Aplique média 3×3 num dígito e mostre antes/depois.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_046.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_046.py
# %run -i labs/exercicios/ex_046.py

# %% [markdown]
# ## EX-047 — Pooling
#
# MaxPool 2×2 em imagem 28×28: saída espacial aproximada?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_047.py`
#
# <details><summary>Gabarito curto</summary>
#
# 14×14
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_047.py
# %run -i labs/exercicios/ex_047.py

# %% [markdown]
# ## EX-048 — Sem Conv2D
#
# Substitua por Dense-only e compare acc (1 epoch ok).
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_048.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_048.py
# %run -i labs/exercicios/ex_048.py

# %% [markdown]
# ## EX-049 — Transfer learning (conceito)
#
# Fine-tune usa pesos de onde?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_049.py`
#
# <details><summary>Gabarito curto</summary>
#
# modelo pré-treinado / outro dataset
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_049.py
# %run -i labs/exercicios/ex_049.py

# %% [markdown]
# ## EX-050 — Domínio diferente
#
# Bom no Fashion-MNIST = pronto para produção? Por quê?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_050.py`
#
# <details><summary>Gabarito curto</summary>
#
# não
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_050.py
# %run -i labs/exercicios/ex_050.py

# %% [markdown]
# ## EX-051 — Canais
#
# Fashion-MNIST tem quantos canais após expand_dims?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_051.py`
#
# <details><summary>Gabarito curto</summary>
#
# 1
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_051.py
# %run -i labs/exercicios/ex_051.py

# %% [markdown]
# ## EX-052 — Normalização /255
#
# Por que dividir por 255?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_052.py`
#
# <details><summary>Gabarito curto</summary>
#
# escalar para [0,1]
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_052.py
# %run -i labs/exercicios/ex_052.py

# %% [markdown]
# ## EX-053 — Lanterna no mural
#
# A analogia da convolução nesta trilha é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_053.py`
#
# <details><summary>Gabarito curto</summary>
#
# lanterna no mural
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_053.py
# %run -i labs/exercicios/ex_053.py

# %% [markdown]
# ## EX-054 — Inspecionar erros
#
# Acurácia sozinha basta? O que mais olhar?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_054.py`
#
# <details><summary>Gabarito curto</summary>
#
# erros / padrões de falha
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_054.py
# %run -i labs/exercicios/ex_054.py

# %% [markdown]
# ## Fecho da aula 04
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
