# %% [markdown]
# # Aula 02 — Treino / loss / backprop (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Wine (sklearn/UCI)**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-015** … **EX-027** (13 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-015** — Wine + MLP → `labs/exercicios/ex_015.py`
# - **EX-016** — Curva de loss → `labs/exercicios/ex_016.py`
# - **EX-017** — Epochs efetivas → `labs/exercicios/ex_017.py`
# - **EX-018** — Overfit proposital → `labs/exercicios/ex_018.py`
# - **EX-019** — Early stopping → `labs/exercicios/ex_019.py`
# - **EX-020** — O que é loss → `labs/exercicios/ex_020.py`
# - **EX-021** — Batch vs epoch → `labs/exercicios/ex_021.py`
# - **EX-022** — Gradiente → `labs/exercicios/ex_022.py`
# - **EX-023** — Learning rate alto → `labs/exercicios/ex_023.py`
# - **EX-024** — Validação vs teste → `labs/exercicios/ex_024.py`
# - **EX-025** — Relatório Wine → `labs/exercicios/ex_025.py`
# - **EX-026** — Matriz de confusão → `labs/exercicios/ex_026.py`
# - **EX-027** — Treino ≠ generalização → `labs/exercicios/ex_027.py`

# %% [markdown]
# ## EX-015 — Wine + MLP
#
# Treine MLP (64,32) no Wine. Qual acc no teste?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_015.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_015.py
# %run -i labs/exercicios/ex_015.py

# %% [markdown]
# ## EX-016 — Curva de loss
#
# Plote loss_curve_. A curva é monótona decrescente?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_016.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_016.py
# %run -i labs/exercicios/ex_016.py

# %% [markdown]
# ## EX-017 — Epochs efetivas
#
# Quantas epochs o Adam rodou (n_iter_)?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_017.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_017.py
# %run -i labs/exercicios/ex_017.py

# %% [markdown]
# ## EX-018 — Overfit proposital
#
# Rede grande + poucos dados: reporte gap treino−teste.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_018.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_018.py
# %run -i labs/exercicios/ex_018.py

# %% [markdown]
# ## EX-019 — Early stopping
#
# Ligue early_stopping e compare epochs e gap.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_019.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_019.py
# %run -i labs/exercicios/ex_019.py

# %% [markdown]
# ## EX-020 — O que é loss
#
# Loss mede o quê em uma frase?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_020.py`
#
# <details><summary>Gabarito curto</summary>
#
# erro da previsão vs rótulo
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_020.py
# %run -i labs/exercicios/ex_020.py

# %% [markdown]
# ## EX-021 — Batch vs epoch
#
# Uma epoch passa por quantos exemplos (em média)?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_021.py`
#
# <details><summary>Gabarito curto</summary>
#
# o conjunto de treino inteiro
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_021.py
# %run -i labs/exercicios/ex_021.py

# %% [markdown]
# ## EX-022 — Gradiente
#
# O gradiente aponta para onde a loss sobe ou desce?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_022.py`
#
# <details><summary>Gabarito curto</summary>
#
# sobe (subimos o negativo)
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_022.py
# %run -i labs/exercicios/ex_022.py

# %% [markdown]
# ## EX-023 — Learning rate alto
#
# LR muito alto tipicamente faz a loss…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_023.py`
#
# <details><summary>Gabarito curto</summary>
#
# oscilar / divergir
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_023.py
# %run -i labs/exercicios/ex_023.py

# %% [markdown]
# ## EX-024 — Validação vs teste
#
# Para escolher hiperparâmetros uso…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_024.py`
#
# <details><summary>Gabarito curto</summary>
#
# validação
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_024.py
# %run -i labs/exercicios/ex_024.py

# %% [markdown]
# ## EX-025 — Relatório Wine
#
# Imprima classification_report e cite a pior classe.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_025.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_025.py
# %run -i labs/exercicios/ex_025.py

# %% [markdown]
# ## EX-026 — Matriz de confusão
#
# Plote a matriz de confusão do Wine.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_026.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_026.py
# %run -i labs/exercicios/ex_026.py

# %% [markdown]
# ## EX-027 — Treino ≠ generalização
#
# Escreva a frase do dia em uma linha.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_027.py`
#
# <details><summary>Gabarito curto</summary>
#
# treino baixo ≠ generalização
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_027.py
# %run -i labs/exercicios/ex_027.py

# %% [markdown]
# ## Fecho da aula 02
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
