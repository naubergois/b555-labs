# %% [markdown]
# # Aula 06 — Pipeline de projeto (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Breast Cancer**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-068** … **EX-080** (13 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-068** — Shapes do split → `labs/exercicios/ex_068.py`
# - **EX-069** — Baseline LR → `labs/exercicios/ex_069.py`
# - **EX-070** — MLP vs baseline → `labs/exercicios/ex_070.py`
# - **EX-071** — Teste uma vez → `labs/exercicios/ex_071.py`
# - **EX-072** — Distribuição de classes → `labs/exercicios/ex_072.py`
# - **EX-073** — Checklist relatório → `labs/exercicios/ex_073.py`
# - **EX-074** — Métrica e custo → `labs/exercicios/ex_074.py`
# - **EX-075** — Vazamento de feature → `labs/exercicios/ex_075.py`
# - **EX-076** — Seed → `labs/exercicios/ex_076.py`
# - **EX-077** — Receita de bolo → `labs/exercicios/ex_077.py`
# - **EX-078** — Baseline primeiro → `labs/exercicios/ex_078.py`
# - **EX-079** — Ética/dados → `labs/exercicios/ex_079.py`
# - **EX-080** — Produto da aula → `labs/exercicios/ex_080.py`

# %% [markdown]
# ## EX-068 — Shapes do split
#
# Breast Cancer: imprima shapes tr/va/te (40/30/30 do resto).
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_068.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_068.py
# %run -i labs/exercicios/ex_068.py

# %% [markdown]
# ## EX-069 — Baseline LR
#
# Treine LogisticRegression. AUC na validação?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_069.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_069.py
# %run -i labs/exercicios/ex_069.py

# %% [markdown]
# ## EX-070 — MLP vs baseline
#
# Compare F1/AUC na validação; escolha um modelo.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_070.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_070.py
# %run -i labs/exercicios/ex_070.py

# %% [markdown]
# ## EX-071 — Teste uma vez
#
# Avalie no teste só o escolhido. Registre os números.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_071.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_071.py
# %run -i labs/exercicios/ex_071.py

# %% [markdown]
# ## EX-072 — Distribuição de classes
#
# Plote % positivos em tr/va/te.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_072.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_072.py
# %run -i labs/exercicios/ex_072.py

# %% [markdown]
# ## EX-073 — Checklist relatório
#
# Marque mentalmente os 7 itens do checklist.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_073.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_073.py
# %run -i labs/exercicios/ex_073.py

# %% [markdown]
# ## EX-074 — Métrica e custo
#
# Se falso negativo é caro, que métrica priorizar?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_074.py`
#
# <details><summary>Gabarito curto</summary>
#
# recall / sensibilidade
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_074.py
# %run -i labs/exercicios/ex_074.py

# %% [markdown]
# ## EX-075 — Vazamento de feature
#
# Usar 'data_cancelamento' para prever churn é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_075.py`
#
# <details><summary>Gabarito curto</summary>
#
# vazamento
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_075.py
# %run -i labs/exercicios/ex_075.py

# %% [markdown]
# ## EX-076 — Seed
#
# Por que fixar random_state=42?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_076.py`
#
# <details><summary>Gabarito curto</summary>
#
# reproducibilidade
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_076.py
# %run -i labs/exercicios/ex_076.py

# %% [markdown]
# ## EX-077 — Receita de bolo
#
# Analogia do pipeline nesta trilha?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_077.py`
#
# <details><summary>Gabarito curto</summary>
#
# receita de bolo
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_077.py
# %run -i labs/exercicios/ex_077.py

# %% [markdown]
# ## EX-078 — Baseline primeiro
#
# Por que baseline antes da rede?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_078.py`
#
# <details><summary>Gabarito curto</summary>
#
# saber se a NN vale a pena
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_078.py
# %run -i labs/exercicios/ex_078.py

# %% [markdown]
# ## EX-079 — Ética/dados
#
# Cite 1 cuidado ético com dados clínicos.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_079.py`
#
# <details><summary>Gabarito curto</summary>
#
# privacidade / consentimento
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_079.py
# %run -i labs/exercicios/ex_079.py

# %% [markdown]
# ## EX-080 — Produto da aula
#
# O artefato desta aula é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_080.py`
#
# <details><summary>Gabarito curto</summary>
#
# pipeline + checklist
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_080.py
# %run -i labs/exercicios/ex_080.py

# %% [markdown]
# ## Fecho da aula 06
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
