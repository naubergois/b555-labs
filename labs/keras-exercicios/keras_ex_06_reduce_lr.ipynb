# %% [markdown]
# # Keras exercício 06 — ReduceLROnPlateau — quando a val estaciona
#
# **B555** · Área: `treino` · Dataset: sklearn load_digits
#
# **O que você aprende:** Se a validação não melhora, reduzir LR finamente em vez de treinar eterno.
#
# **Métrica:** val_accuracy + histórico de LR
#
# **Limite:** LR pequeno demais trava o aprendizado.
#
# Frase-guia: *a rede calcula; nós decidimos*.

# %%
# %pip install -q tensorflow scikit-learn numpy
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.random.set_seed(7); np.random.seed(7)
X, y = load_digits(return_X_y=True)
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.25, random_state=7, stratify=y)
sc = StandardScaler(); Xtr, Xte = sc.fit_transform(Xtr), sc.transform(Xte)
model = keras.Sequential([layers.Input(shape=(64,)), layers.Dense(64, activation='relu'), layers.Dense(10, activation='softmax')])
model.compile(optimizer=keras.optimizers.Adam(1e-2), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cb = [keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)]
model.fit(Xtr, ytr, validation_split=0.2, epochs=25, callbacks=cb, verbose=0)
print('acc teste', model.evaluate(Xte, yte, verbose=0)[1])

# %% [markdown]
# ## Depois de rodar
#
# 1. Anote a métrica de teste.
# 2. Escreva em uma frase o que a rede **não** decide.
# 3. Se for saúde/proxy: declare que **não é dispositivo médico**.
