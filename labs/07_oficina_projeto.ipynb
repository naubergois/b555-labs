# %% [markdown]
# # Aula 07 — Oficina do projeto (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Wine (trocável)**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-081** … **EX-090** (10 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-081** — Wine binário setup → `labs/exercicios/ex_081.py`
# - **EX-082** — Sprint baseline → `labs/exercicios/ex_082.py`
# - **EX-083** — Ablação tamanho → `labs/exercicios/ex_083.py`
# - **EX-084** — Ablação L2 → `labs/exercicios/ex_084.py`
# - **EX-085** — Evidência|risco|ação → `labs/exercicios/ex_085.py`
# - **EX-086** — MVP → `labs/exercicios/ex_086.py`
# - **EX-087** — Não misturar fatores → `labs/exercicios/ex_087.py`
# - **EX-088** — Checkpoint → `labs/exercicios/ex_088.py`
# - **EX-089** — Demo que roda → `labs/exercicios/ex_089.py`
# - **EX-090** — Menor móvel útil → `labs/exercicios/ex_090.py`

# %% [markdown]
# ## EX-081 — Wine binário setup
#
# Transforme Wine em classe0 vs resto e mostre balance.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_081.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_081.py
# %run -i labs/exercicios/ex_081.py

# %% [markdown]
# ## EX-082 — Sprint baseline
#
# Obtenha F1_val do baseline em <2 min de código.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_082.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_082.py
# %run -i labs/exercicios/ex_082.py

# %% [markdown]
# ## EX-083 — Ablação tamanho
#
# Compare MLP (16,) vs (64,32) na validação.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_083.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_083.py
# %run -i labs/exercicios/ex_083.py

# %% [markdown]
# ## EX-084 — Ablação L2
#
# Compare com/sem L2 forte na MLP.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_084.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_084.py
# %run -i labs/exercicios/ex_084.py

# %% [markdown]
# ## EX-085 — Evidência|risco|ação
#
# Preencha as 3 colunas em uma linha cada.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_085.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_085.py
# %run -i labs/exercicios/ex_085.py

# %% [markdown]
# ## EX-086 — MVP
#
# O menor experimento útil desta oficina é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_086.py`
#
# <details><summary>Gabarito curto</summary>
#
# baseline + rede mínima comparáveis
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_086.py
# %run -i labs/exercicios/ex_086.py

# %% [markdown]
# ## EX-087 — Não misturar fatores
#
# Por que mudar um hiperparâmetro por vez?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_087.py`
#
# <details><summary>Gabarito curto</summary>
#
# saber o que ajudou
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_087.py
# %run -i labs/exercicios/ex_087.py

# %% [markdown]
# ## EX-088 — Checkpoint
#
# Liste 3 itens do checklist_oficina.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_088.py`
#
# <details><summary>Gabarito curto</summary>
#
# baseline, split, evidência…
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_088.py
# %run -i labs/exercicios/ex_088.py

# %% [markdown]
# ## EX-089 — Demo que roda
#
# Demo só no notebook local sem README: passa?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_089.py`
#
# <details><summary>Gabarito curto</summary>
#
# não (reproducibilidade)
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_089.py
# %run -i labs/exercicios/ex_089.py

# %% [markdown]
# ## EX-090 — Menor móvel útil
#
# Analogia da oficina?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_090.py`
#
# <details><summary>Gabarito curto</summary>
#
# menor móvel útil
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_090.py
# %run -i labs/exercicios/ex_090.py

# %% [markdown]
# ## Fecho da aula 07
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
