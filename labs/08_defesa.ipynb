# %% [markdown]
# # Aula 08 — Defesa e fechamento (Colab)
#
# **B555 · Redes Neurais** · Dataset livre: **Wine + rubrica**
#
# Este notebook **clona o GitHub** [`naubergois/redesneurais`](https://github.com/naubergois/redesneurais) e roda os scripts
# autocontidos em `labs/exercicios/ex_XXX.py` (código completo + imagem).
#
# Exercícios: **EX-091** … **EX-104** (14 itens).
#
# 1. Rode a célula de clone
# 2. Rode cada exercício (`%run`)
# 3. Ou no terminal: `python labs/exercicios/ex_00N.py`

# %%
# 1) Instala deps + clona o repositório com TODO o código dos exercícios
# %pip install -q numpy pandas scikit-learn matplotlib

import os
import sys
import subprocess
from pathlib import Path

REPO_URL = "https://github.com/naubergois/redesneurais.git"
REPO_NAME = "redesneurais"

# Colab usa /content; local usa o diretório atual
base = Path("/content") if Path("/content").is_dir() else Path.cwd()
repo = base / REPO_NAME

if not (repo / "labs" / "exercicios" / "common.py").is_file():
    subprocess.run(
        ["git", "clone", "--depth", "1", REPO_URL, str(repo)],
        check=True,
    )
else:
    print("Repositório já presente:", repo)

os.chdir(repo)
sys.path.insert(0, str(repo / "labs" / "exercicios"))
print("cwd =", Path.cwd())
print("exercícios =", len(list((repo / "labs" / "exercicios").glob("ex_*.py"))))

# %% [markdown]
# ## Índice
#
# - **EX-091** — Revalidar protocolo → `labs/exercicios/ex_091.py`
# - **EX-092** — Roteiro 10 min → `labs/exercicios/ex_092.py`
# - **EX-093** — Checklist oral → `labs/exercicios/ex_093.py`
# - **EX-094** — Manter baseline → `labs/exercicios/ex_094.py`
# - **EX-095** — Exemplo de erro → `labs/exercicios/ex_095.py`
# - **EX-096** — Recomendação em 2 frases → `labs/exercicios/ex_096.py`
# - **EX-097** — História no elevador → `labs/exercicios/ex_097.py`
# - **EX-098** — Frequência 75% → `labs/exercicios/ex_098.py`
# - **EX-099** — Média 7 → `labs/exercicios/ex_099.py`
# - **EX-100** — O que a defesa NÃO é → `labs/exercicios/ex_100.py`
# - **EX-101** — Feedback útil → `labs/exercicios/ex_101.py`
# - **EX-102** — Slides da rubrica → `labs/exercicios/ex_102.py`
# - **EX-103** — Frase-guia final → `labs/exercicios/ex_103.py`
# - **EX-104** — Fechamento → `labs/exercicios/ex_104.py`

# %% [markdown]
# ## EX-091 — Revalidar protocolo
#
# Rode baseline vs MLP e anote F1_val e F1_te.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_091.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_091.py
# %run -i labs/exercicios/ex_091.py

# %% [markdown]
# ## EX-092 — Roteiro 10 min
#
# Monte o outline 1–2–1–2–2–2 min.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_092.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_092.py
# %run -i labs/exercicios/ex_092.py

# %% [markdown]
# ## EX-093 — Checklist oral
#
# Responda sim/não aos 5 itens do checklist oral.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_093.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_093.py
# %run -i labs/exercicios/ex_093.py

# %% [markdown]
# ## EX-094 — Manter baseline
#
# Manter o baseline é válido na rubrica?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_094.py`
#
# <details><summary>Gabarito curto</summary>
#
# sim
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_094.py
# %run -i labs/exercicios/ex_094.py

# %% [markdown]
# ## EX-095 — Exemplo de erro
#
# Mostre 1 caso em que o modelo erra (índice + features).
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_095.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_095.py
# %run -i labs/exercicios/ex_095.py

# %% [markdown]
# ## EX-096 — Recomendação em 2 frases
#
# Escreva evidência → ação.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_096.py`
#
# <details><summary>Gabarito curto</summary>
#
# _interprete a figura_
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_096.py
# %run -i labs/exercicios/ex_096.py

# %% [markdown]
# ## EX-097 — História no elevador
#
# Analogia da defesa?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_097.py`
#
# <details><summary>Gabarito curto</summary>
#
# história no elevador
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_097.py
# %run -i labs/exercicios/ex_097.py

# %% [markdown]
# ## EX-098 — Frequência 75%
#
# Limiar institucional de frequência?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_098.py`
#
# <details><summary>Gabarito curto</summary>
#
# ≥75%
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_098.py
# %run -i labs/exercicios/ex_098.py

# %% [markdown]
# ## EX-099 — Média 7
#
# Limiar de média?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_099.py`
#
# <details><summary>Gabarito curto</summary>
#
# ≥7
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_099.py
# %run -i labs/exercicios/ex_099.py

# %% [markdown]
# ## EX-100 — O que a defesa NÃO é
#
# É concurso SOTA?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_100.py`
#
# <details><summary>Gabarito curto</summary>
#
# não
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_100.py
# %run -i labs/exercicios/ex_100.py

# %% [markdown]
# ## EX-101 — Feedback útil
#
# Feedback ácido sobre método é…
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_101.py`
#
# <details><summary>Gabarito curto</summary>
#
# presente / útil
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_101.py
# %run -i labs/exercicios/ex_101.py

# %% [markdown]
# ## EX-102 — Slides da rubrica
#
# Quantos slides alvo (faixa)?
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_102.py`
#
# <details><summary>Gabarito curto</summary>
#
# 8–10
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_102.py
# %run -i labs/exercicios/ex_102.py

# %% [markdown]
# ## EX-103 — Frase-guia final
#
# Repita a frase-guia do curso.
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_103.py`
#
# <details><summary>Gabarito curto</summary>
#
# a rede calcula; nós decidimos
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_103.py
# %run -i labs/exercicios/ex_103.py

# %% [markdown]
# ## EX-104 — Fechamento
#
# Liste artefatos a entregar (ZIP/Git + deck).
#
# Arquivo completo no repo (após o clone): `labs/exercicios/ex_104.py`
#
# <details><summary>Gabarito curto</summary>
#
# código+README+deck
#
# </details>

# %%
# Código completo no GitHub (já clonado na 1ª célula)
# Equivalente: python labs/exercicios/ex_104.py
# %run -i labs/exercicios/ex_104.py

# %% [markdown]
# ## Fecho da aula 08
#
# Todos os exercícios desta aula rodam com o código do repositório clonado.
# Frase-guia: **a rede calcula; nós decidimos.**
